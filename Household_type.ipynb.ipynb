# %%
# Dependencies
import requests
import json
from config import api_key
from config import gkey
import census
from census import Census
import pandas as pd
import matplotlib.pyplot as plt
import us
from us import states

# %%
# Household type from year 2011
c_household_type_2011 = Census(api_key, year=2011)
household_type_2011 = c_household_type_2011.acs5.get(("NAME","B11001_001E","B11001_002E","B11001_003E","B11001_004E","B11001_005E","B11001_006E","B11001_007E","B11001_008E","B11001_009E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame
household_type_2011 = pd.DataFrame(household_type_2011)

# Column Reordering
household_type_2011 = household_type_2011.rename(columns={"B11001_001E":"Estimate!!Total","B11001_002E": "Estimate!!Total!!Family households","B11001_003E": "Estimate!!Total!!Family households!!Married-couple family","B11001_004E": "Estimate!!Total!!Family households!!Other family","B11001_005E": "Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                                      "B11001_006E": "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","B11001_007E":"Estimate!!Total!!Nonfamily households",
                                                                      "B11001_008E":"Estimate!!Total!!Nonfamily households!!Householder living alone","B11001_009E":"Estimate!!Total!!Nonfamily households!!Householder not living alone",
                                                                        "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
household_type_2011 = household_type_2011 [["Zipcode","Estimate!!Total","Estimate!!Total!!Family households","Estimate!!Total!!Family households!!Married-couple family",
                                                        "Estimate!!Total!!Family households!!Other family","Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                       "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","Estimate!!Total!!Nonfamily households",
                                                       "Estimate!!Total!!Nonfamily households!!Householder living alone","Estimate!!Total!!Nonfamily households!!Householder not living alone"]]

# Visualize
print(len(household_type_2011))

# Save to csv
household_type_2011.to_csv('household_type_2011_EO.csv',index=False)

household_type_2011
# Out:
# 133
#     Zipcode  Estimate!!Total  Estimate!!Total!!Family households  \
# 0     77002           2741.0                               411.0
# 1     77003           3949.0                              1790.0
# 2     77004          12352.0                              5026.0
# 3     77005           9535.0                              6240.0
# 4     77006          11481.0                              3038.0
# 5     77007          14506.0                              5580.0
# 6     77008          14227.0                              6911.0
# 7     77009          13877.0                              8289.0
# 8     77010            154.0                                45.0
# 9     77011           5834.0                              4452.0
# 10    77012           6289.0                              4659.0
# 11    77013           5434.0                              4231.0
# 12    77014           9550.0                              6684.0
# ...

# %%
# Household type from year 2012
c_household_type_2012 = Census(api_key, year=2012)
household_type_2012 = c_household_type_2012.acs5.get(("NAME","B11001_001E","B11001_002E","B11001_003E","B11001_004E","B11001_005E","B11001_006E","B11001_007E","B11001_008E","B11001_009E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame
household_type_2012 = pd.DataFrame(household_type_2012)

# Column Reordering
household_type_2012 = household_type_2012.rename(columns={"B11001_001E":"Estimate!!Total","B11001_002E": "Estimate!!Total!!Family households","B11001_003E": "Estimate!!Total!!Family households!!Married-couple family","B11001_004E": "Estimate!!Total!!Family households!!Other family","B11001_005E": "Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                                      "B11001_006E": "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","B11001_007E":"Estimate!!Total!!Nonfamily households",
                                                                      "B11001_008E":"Estimate!!Total!!Nonfamily households!!Householder living alone","B11001_009E":"Estimate!!Total!!Nonfamily households!!Householder not living alone",
                                                                        "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
household_type_2012 = household_type_2012 [["Zipcode","Estimate!!Total","Estimate!!Total!!Family households","Estimate!!Total!!Family households!!Married-couple family",
                                                        "Estimate!!Total!!Family households!!Other family","Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                       "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","Estimate!!Total!!Nonfamily households",
                                                       "Estimate!!Total!!Nonfamily households!!Householder living alone","Estimate!!Total!!Nonfamily households!!Householder not living alone"]]

# Visualize
print(len(household_type_2012))

# Save to csv
household_type_2012.to_csv('household_type_2012_EO.csv',index=False)

household_type_2012
# Out:
# 133
#     Zipcode  Estimate!!Total  Estimate!!Total!!Family households  \
# 0     77484           3571.0                              2708.0
# 1     77493           7090.0                              5725.0
# 2     77502          10693.0                              8029.0
# 3     77503           7659.0                              5478.0
# 4     77504           8534.0                              5721.0
# 5     77505           8147.0                              6207.0
# 6     77506          10531.0                              7900.0
# 7     77507              0.0                                 0.0
# 8     77520          11981.0                              8434.0
# 9     77521          16905.0                             12775.0
# 10    77530           9018.0                              7104.0
# 11    77532           8862.0                              7151.0
# 12    77536          10517.0                              8718.0
# ...

# %%
# Household type from year 2013
c_household_type_2013= Census(api_key, year=2013)
household_type_2013 = c_household_type_2013.acs5.get(("NAME","B11001_001E","B11001_002E","B11001_003E","B11001_004E","B11001_005E","B11001_006E","B11001_007E","B11001_008E","B11001_009E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame
household_type_2013 = pd.DataFrame(household_type_2013)

# Column Reordering
household_type_2013 = household_type_2013.rename(columns={"B11001_001E":"Estimate!!Total","B11001_002E": "Estimate!!Total!!Family households","B11001_003E": "Estimate!!Total!!Family households!!Married-couple family","B11001_004E": "Estimate!!Total!!Family households!!Other family","B11001_005E": "Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                                      "B11001_006E": "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","B11001_007E":"Estimate!!Total!!Nonfamily households",
                                                                      "B11001_008E":"Estimate!!Total!!Nonfamily households!!Householder living alone","B11001_009E":"Estimate!!Total!!Nonfamily households!!Householder not living alone",
                                                                        "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
household_type_2013 = household_type_2013 [["Zipcode","Estimate!!Total","Estimate!!Total!!Family households","Estimate!!Total!!Family households!!Married-couple family",
                                                        "Estimate!!Total!!Family households!!Other family","Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                       "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","Estimate!!Total!!Nonfamily households",
                                                       "Estimate!!Total!!Nonfamily households!!Householder living alone","Estimate!!Total!!Nonfamily households!!Householder not living alone"]]

# Visualize
print(len(household_type_2013))

# Save to csv
household_type_2013.to_csv('household_type_2013_EO.csv',index=False)

household_type_2013
# Out:
# 133
#     Zipcode  Estimate!!Total  Estimate!!Total!!Family households  \
# 0     77562           3538.0                              2593.0
# 1     77571          12277.0                              9393.0
# 2     77586           8236.0                              5443.0
# 3     77587           4717.0                              3709.0
# 4     77598           9905.0                              4988.0
# 5     77002           3035.0                               524.0
# 6     77003           4255.0                              2158.0
# 7     77004          12536.0                              5566.0
# 8     77005           9420.0                              6421.0
# 9     77006          11595.0                              3280.0
# 10    77007          15940.0                              6167.0
# 11    77008          14742.0                              7058.0
# 12    77009          14046.0                              8367.0
# ...

# %%
# Household type from year 2014
c_household_type_2014= Census(api_key, year=2014)
household_type_2014 = c_household_type_2014.acs5.get(("NAME","B11001_001E","B11001_002E","B11001_003E","B11001_004E","B11001_005E","B11001_006E","B11001_007E","B11001_008E","B11001_009E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame
household_type_2014 = pd.DataFrame(household_type_2014)

# Column Reordering
household_type_2014 = household_type_2014.rename(columns={"B11001_001E":"Estimate!!Total","B11001_002E": "Estimate!!Total!!Family households","B11001_003E": "Estimate!!Total!!Family households!!Married-couple family","B11001_004E": "Estimate!!Total!!Family households!!Other family","B11001_005E": "Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                                      "B11001_006E": "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","B11001_007E":"Estimate!!Total!!Nonfamily households",
                                                                      "B11001_008E":"Estimate!!Total!!Nonfamily households!!Householder living alone","B11001_009E":"Estimate!!Total!!Nonfamily households!!Householder not living alone",
                                                                        "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
household_type_2014 = household_type_2014 [["Zipcode","Estimate!!Total","Estimate!!Total!!Family households","Estimate!!Total!!Family households!!Married-couple family",
                                                        "Estimate!!Total!!Family households!!Other family","Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                       "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","Estimate!!Total!!Nonfamily households",
                                                       "Estimate!!Total!!Nonfamily households!!Householder living alone","Estimate!!Total!!Nonfamily households!!Householder not living alone"]]

# Visualize
print(len(household_type_2014))

# Save to csv
household_type_2014.to_csv('household_type_2014_EO.csv',index=False)

household_type_2014
# Out:
# 133
#     Zipcode  Estimate!!Total  Estimate!!Total!!Family households  \
# 0     77520          12131.0                              8652.0
# 1     77521          17771.0                             13308.0
# 2     77530           9098.0                              6872.0
# 3     77532           9364.0                              7729.0
# 4     77536          10797.0                              8677.0
# 5     77547           2695.0                              2193.0
# 6     77562           3558.0                              2697.0
# 7     77571          12309.0                              9390.0
# 8     77586           8392.0                              5467.0
# 9     77587           4591.0                              3771.0
# 10    77598          10070.0                              5079.0
# 11    77002           2981.0                               508.0
# 12    77003           4344.0                              2082.0
# ...

# %%
# Household type from year 2015
c_household_type_2015= Census(api_key, year=2015)
household_type_2015 = c_household_type_2015.acs5.get(("NAME","B11001_001E","B11001_002E","B11001_003E","B11001_004E","B11001_005E","B11001_006E","B11001_007E","B11001_008E","B11001_009E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame
household_type_2015 = pd.DataFrame(household_type_2015)

# Column Reordering
household_type_2015 = household_type_2015.rename(columns={"B11001_001E":"Estimate!!Total","B11001_002E": "Estimate!!Total!!Family households","B11001_003E": "Estimate!!Total!!Family households!!Married-couple family","B11001_004E": "Estimate!!Total!!Family households!!Other family","B11001_005E": "Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                                      "B11001_006E": "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","B11001_007E":"Estimate!!Total!!Nonfamily households",
                                                                      "B11001_008E":"Estimate!!Total!!Nonfamily households!!Householder living alone","B11001_009E":"Estimate!!Total!!Nonfamily households!!Householder not living alone",
                                                                        "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
household_type_2015 = household_type_2015 [["Zipcode","Estimate!!Total","Estimate!!Total!!Family households","Estimate!!Total!!Family households!!Married-couple family",
                                                        "Estimate!!Total!!Family households!!Other family","Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                       "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","Estimate!!Total!!Nonfamily households",
                                                       "Estimate!!Total!!Nonfamily households!!Householder living alone","Estimate!!Total!!Nonfamily households!!Householder not living alone"]]

# Visualize
print(len(household_type_2015))

# Save to csv
household_type_2015.to_csv('household_type_2015_EO.csv',index=False)

household_type_2015
# Out:
# 133
#     Zipcode  Estimate!!Total  Estimate!!Total!!Family households  \
# 0     77002           3185.0                               563.0
# 1     77003           4363.0                              1978.0
# 2     77004          12892.0                              5642.0
# 3     77005           9691.0                              6689.0
# 4     77006          11894.0                              3628.0
# 5     77007          17211.0                              6843.0
# 6     77008          15283.0                              7582.0
# 7     77009          14072.0                              8465.0
# 8     77010            510.0                               192.0
# 9     77011           5629.0                              4106.0
# 10    77012           6144.0                              4304.0
# 11    77013           5762.0                              4321.0
# 12    77014          11101.0                              7903.0
# ...

# %%
# Household type from year 2016
c_household_type_2016= Census(api_key, year=2016)
household_type_2016 = c_household_type_2016.acs5.get(("NAME","B11001_001E","B11001_002E","B11001_003E","B11001_004E","B11001_005E","B11001_006E","B11001_007E","B11001_008E","B11001_009E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame
household_type_2016 = pd.DataFrame(household_type_2016)

# Column Reordering
household_type_2016 = household_type_2016.rename(columns={"B11001_001E":"Estimate!!Total","B11001_002E": "Estimate!!Total!!Family households","B11001_003E": "Estimate!!Total!!Family households!!Married-couple family","B11001_004E": "Estimate!!Total!!Family households!!Other family","B11001_005E": "Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                                      "B11001_006E": "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","B11001_007E":"Estimate!!Total!!Nonfamily households",
                                                                      "B11001_008E":"Estimate!!Total!!Nonfamily households!!Householder living alone","B11001_009E":"Estimate!!Total!!Nonfamily households!!Householder not living alone",
                                                                        "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
household_type_2016 = household_type_2016 [["Zipcode","Estimate!!Total","Estimate!!Total!!Family households","Estimate!!Total!!Family households!!Married-couple family",
                                                        "Estimate!!Total!!Family households!!Other family","Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                       "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","Estimate!!Total!!Nonfamily households",
                                                       "Estimate!!Total!!Nonfamily households!!Householder living alone","Estimate!!Total!!Nonfamily households!!Householder not living alone"]]

# Visualize
print(len(household_type_2016))

# Save to csv
household_type_2016.to_csv('household_type_2016_EO.csv',index=False)

household_type_2016
# Out:
# 133
#     Zipcode  Estimate!!Total  Estimate!!Total!!Family households  \
# 0     77586           8580.0                              5362.0
# 1     77587           4551.0                              3714.0
# 2     77598          10354.0                              5032.0
# 3     77002           3248.0                               595.0
# 4     77003           4434.0                              1909.0
# 5     77004          13097.0                              5823.0
# 6     77005           9899.0                              6898.0
# 7     77006          12159.0                              3467.0
# 8     77007          18345.0                              7502.0
# 9     77008          15671.0                              7723.0
# 10    77009          14260.0                              8569.0
# 11    77010            529.0                               198.0
# 12    77011           5511.0                              4043.0
# ...

# %%
# Household type from year 2017.
c_household_type_2017= Census(api_key, year=2017)
household_type_2017 = c_household_type_2017.acs5.get(("NAME","B11001_001E","B11001_002E","B11001_003E","B11001_004E","B11001_005E","B11001_006E","B11001_007E","B11001_008E","B11001_009E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame
household_type_2017 = pd.DataFrame(household_type_2017)

# Column Reordering
household_type_2017 = household_type_2017.rename(columns={"B11001_001E":"Estimate!!Total","B11001_002E": "Estimate!!Total!!Family households","B11001_003E": "Estimate!!Total!!Family households!!Married-couple family","B11001_004E": "Estimate!!Total!!Family households!!Other family","B11001_005E": "Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                                      "B11001_006E": "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","B11001_007E":"Estimate!!Total!!Nonfamily households",
                                                                      "B11001_008E":"Estimate!!Total!!Nonfamily households!!Householder living alone","B11001_009E":"Estimate!!Total!!Nonfamily households!!Householder not living alone",
                                                                        "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
household_type_2017 = household_type_2017 [["Zipcode","Estimate!!Total","Estimate!!Total!!Family households","Estimate!!Total!!Family households!!Married-couple family",
                                                        "Estimate!!Total!!Family households!!Other family","Estimate!!Total!!Family households!!Other family!!Male householder, no wife present",
                                                       "Estimate!!Total!!Family households!!Other family!!Female householder, no husband present","Estimate!!Total!!Nonfamily households",
                                                       "Estimate!!Total!!Nonfamily households!!Householder living alone","Estimate!!Total!!Nonfamily households!!Householder not living alone"]]

# Visualize
print(len(household_type_2017))

# Save to csv
household_type_2017.to_csv('household_type_2017_EO.csv',index=False)

household_type_2017
# Out:
# 133
#     Zipcode  Estimate!!Total  Estimate!!Total!!Family households  \
# 0     77003           4470.0                              1851.0
# 1     77375          16125.0                             11790.0
# 2     77002           3295.0                               482.0
# 3     77091           9658.0                              6000.0
# 4     77024          15252.0                             10227.0
# 5     77036          26852.0                             16872.0
# 6     77046            719.0                               204.0
# 7     77049          10236.0                              7891.0
# 8     77061           8690.0                              5939.0
# 9     77073          12824.0                              9791.0
# 10    77076           9756.0                              7483.0
# 11    77079          12496.0                              8879.0
# 12    77080          15241.0                             10262.0
# ...
