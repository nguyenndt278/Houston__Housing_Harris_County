# %%
# Dependencies
import requests
import json
from config import api_key
from config import gkey
import census
from census import Census
import pandas as pd
import matplotlib.pyplot as plt
import us
from us import states


# Load Files

HH_Workforce2011_Raw_NN_data = "HH_Workforce2011_Raw_NN.csv"
HH_Workforce2012_Raw_NN_data = "HH_Workforce2012_Raw_NN.csv"
HH_Workforce2013_Raw_NN_data = "HH_Workforce2013_Raw_NN.csv"
HH_Workforce2014_Raw_NN_data = "HH_Workforce2014_Raw_NN.csv"
HH_Workforce2015_Raw_NN_data = "HH_Workforce2015_Raw_NN.csv"
HH_Workforce2016_Raw_NN_data = "HH_Workforce2016_Raw_NN.csv"
HH_Workforce2017_Raw_NN_data = "HH_Workforce2017_Raw_NN.csv"



# Read household_type data from 2011 to 2017
HH_Workforce2011_Clean_NN_data = pd.read_csv(HH_Workforce2011_Raw_NN_data)
HH_Workforce2012_Clean_NN_data = pd.read_csv(HH_Workforce2012_Raw_NN_data)
HH_Workforce2013_Clean_NN_data = pd.read_csv(HH_Workforce2013_Raw_NN_data)
HH_Workforce2014_Clean_NN_data = pd.read_csv(HH_Workforce2014_Raw_NN_data)
HH_Workforce2015_Clean_NN_data = pd.read_csv(HH_Workforce2015_Raw_NN_data)
HH_Workforce2016_Clean_NN_data = pd.read_csv(HH_Workforce2016_Raw_NN_data)
HH_Workforce2017_Clean_NN_data = pd.read_csv(HH_Workforce2017_Raw_NN_data)

# Display the data table for preview

HH_Workforce2017_Clean_NN_data=HH_Workforce2017_Clean_NN_data.drop([6,46,132,72])

HH_Workforce2017_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')

#Save file
HH_Workforce2017_Clean_NN_data.to_csv('HH_Workforce2017_Clean_NN-EO.csv',index=False)

# %%
HH_Workforce2016_Clean_NN_data=HH_Workforce2016_Clean_NN_data.drop([98,124,11,47])

#HH_Workforce2016_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')

HH_Workforce2016_Clean_NN_data.to_csv('HH_Workforce2016_Clean_NN-EO.csv',index=False)

HH_Workforce2016_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')
# Out:
#      Zipcode  Total employed in civilian labor force  \
# 3      77002                                  3433.0
# 51     77050                                  2110.0
# 131    77562                                  4143.0
# 130    77547                                  4303.0
# 31     77030                                  5831.0
# 93     77094                                  4364.0
# 4      77003                                  5584.0
# 33     77032                                  4384.0
# 52     77051                                  5194.0
# 29     77028                                  5635.0
# 96     77098                                  9296.0
# 117    77484                                  5013.0
# 77     77078                                  5837.0
# 30     77029                                  6981.0
# 28     77027                                 10332.0
# 67     77068                                  6073.0
# 111    77401                                  8925.0
# ...

# %%
HH_Workforce2015_Clean_NN_data=HH_Workforce2015_Clean_NN_data.drop([98,124,11,47])

#HH_Workforce2015_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')

#Save file
HH_Workforce2015_Clean_NN_data.to_csv('HH_Workforce2015_Clean_NN-EO.csv',index=False)

HH_Workforce2015_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')
# Out:
#      Zipcode  Total employed in civilian labor force  \
# 3      77002                                  3433.0
# 51     77050                                  2110.0
# 131    77562                                  4143.0
# 130    77547                                  4303.0
# 31     77030                                  5831.0
# 93     77094                                  4364.0
# 4      77003                                  5584.0
# 33     77032                                  4384.0
# 52     77051                                  5194.0
# 29     77028                                  5635.0
# 96     77098                                  9296.0
# 117    77484                                  5013.0
# 77     77078                                  5837.0
# 30     77029                                  6981.0
# 28     77027                                 10332.0
# 67     77068                                  6073.0
# 111    77401                                  8925.0
# ...

# %%
HH_Workforce2014_Clean_NN_data=HH_Workforce2014_Clean_NN_data.drop([19,55,132,106])

#HH_Workforce2014_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')

#save file
HH_Workforce2014_Clean_NN_data.to_csv('HH_Workforce2014_Clean_NN-EO.csv',index=False)

HH_Workforce2014_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')
# Out:
#      Zipcode  Total employed in civilian labor force  \
# 11     77002                                  3202.0
# 59     77050                                  2172.0
# 5      77547                                  3945.0
# 39     77030                                  5979.0
# 60     77051                                  4534.0
# 41     77032                                  3972.0
# 6      77562                                  4547.0
# 101    77094                                  4295.0
# 12     77003                                  5353.0
# 37     77028                                  5443.0
# 38     77029                                  6014.0
# 75     77068                                  5585.0
# 85     77078                                  5171.0
# 9      77587                                  6848.0
# 125    77484                                  5218.0
# 119    77401                                  8854.0
# 104    77098                                  9429.0
# ...

# %%
HH_Workforce2013_Clean_NN_data=HH_Workforce2013_Clean_NN_data.drop([13,49,126,100])

#HH_Workforce2013_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')
#save file
HH_Workforce2013_Clean_NN_data.to_csv('HH_Workforce2013_Clean_NN-EO.csv',index=False)

HH_Workforce2013_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-285-7f0a69529a64> in <module>
# ----> 1 HH_Workforce2013_Clean_NN_data=HH_Workforce2013_Clean_NN_data.drop([13,49,126,100])
#       2
#       3 #HH_Workforce2013_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')
#       4 #save file
#       5 HH_Workforce2013_Clean_NN_data.to_csv('HH_Workforce2013_Clean_NN-EO.csv',index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...

# %%
HH_Workforce2012_Clean_NN_data=HH_Workforce2012_Clean_NN_data.drop([])

#HH_Workforce2012_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')

#save file
HH_Workforce2012_Clean_NN_data.to_csv('HH_Workforce2012_Clean_NN-EO.csv',index=False)

HH_Workforce2012_Clean_NN_data.sort_values(by='Total employed in civilian labor force')
# Out:
#      Zipcode  Total employed in civilian labor force  \
# 67     77050                                  1782.0
# 13     77547                                  3701.0
# 49     77032                                  3708.0
# 109    77094                                  3986.0
# 14     77562                                  4553.0
# 68     77051                                  4569.0
# 20     77003                                  4805.0
# 0      77484                                  5259.0
# 115    77336                                  5458.0
# 93     77078                                  5475.0
# 83     77068                                  5571.0
# 130    77447                                  5686.0
# 47     77030                                  6208.0
# 45     77028                                  6218.0
# 46     77029                                  6258.0
# 65     77048                                  6264.0
# 17     77587                                  6874.0
# ...

# %%
HH_Workforce2011_Clean_NN_data=HH_Workforce2011_Clean_NN_data.drop([8,44,95,121])

#HH_Workforce2011_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')

#save file
HH_Workforce2011_Clean_NN_data.to_csv('HH_Workforce2011_Clean_NN-EO.csv',index=False)

HH_Workforce2011_Clean_NN_data.sort_values(by='Total employed in civilian labor force')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-294-a4c90d587915> in <module>
# ----> 1 HH_Workforce2011_Clean_NN_data=HH_Workforce2011_Clean_NN_data.drop([8,44,95,121])
#       2
#       3 #HH_Workforce2011_Clean_NN_data.sort_values(by='Aggregate travel time to work (in minutes)')
#       4
#       5 #save file
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3827         return super(Series, self).drop(labels=labels, axis=axis, index=index,
#    3828                                         columns=columns, level=level,
# -> 3829                                         inplace=inplace, errors=errors)
#    3830
#    3831     @Substitution(**_shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
#HH_Workforce2011_Clean_NN_data=HH_Workforce2011_Clean_NN_data.mean(axis=1)
#HH_Workforce2011_Clean_NN_data

# Add in Poverty Rate (Poverty Count / Population)
HH_Workforce2011_Clean_NN_data["Average_Travel_Time"]= HH_Workforce2011_Clean_NN_data["Aggregate travel time to work (in minutes)"].astype(int) / HH_Workforce2011_Clean_NN_data["Total employed in civilian labor force"].astype(int)
# Final DataFrame
HH_Workforce2011_Clean_NN_data = HH_Workforce2011_Clean_NN_data[["Zipcode", "Average_Travel_Time", "Total employed in civilian labor force","Aggregate travel time to work (in minutes)"]]

#this is to create a new column and add it to the current data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-295-e33b2b739466> in <module>
#       3
#       4 # Add in Poverty Rate (Poverty Count / Population)
# ----> 5 HH_Workforce2011_Clean_NN_data["Average_Travel_Time"]= HH_Workforce2011_Clean_NN_data["Aggregate travel time to work (in minutes)"].astype(int) / HH_Workforce2011_Clean_NN_data["Total employed in civilian labor force"].astype(int)
#       6 # Final DataFrame
#       7 HH_Workforce2011_Clean_NN_data = HH_Workforce2011_Clean_NN_data[["Zipcode", "Average_Travel_Time", "Total employed in civilian labor force", "Aggregate travel time to work (in minutes)"]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
# ...
