# %%
# Dependencies
import requests
import json
from config import api_key
from config import gkey
import census
from census import Census
import pandas as pd
import matplotlib.pyplot as plt
import us
from us import states

# %%
# Poverty level from year 2011
c_poverty_level_2011 = Census(api_key, year=2011)
poverty_level_2011 = c_poverty_level_2011.acs5.get(("NAME","B07012_001E","B07012_002E","B07012_003E","B07012_004E","B07012_005E","B07012_006E","B07012_007E","B07012_008E","B07012_009E","B07012_010E","B07012_011E","B07012_012E",
                                                   "B07012_013E","B07012_014E","B07012_015E","B07012_016E","B07012_017E","B07012_018E","B07012_019E","B07012_020E","B07012_021E","B07012_022E","B07012_023E","B07012_024E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame
poverty_level_2011= pd.DataFrame(poverty_level_2011)

# Column Reordering
poverty_level_2011= poverty_level_2011.rename(columns={"B07012_001E":"Estimate!!Total","B07012_002E":"Estimate!!Total!!Below 100 percent of the poverty level","B07012_003E":"Estimate!!Total!!100 to 149 percent of the poverty level","B07012_004E":"Estimate!!Total!!At or above 150 percent of the poverty level","B07012_005E":"Estimate!!Total!!Same house 1 year ago","B07012_006E":"Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level","B07012_007E":"Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","B07012_008E":"Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                              "B07012_009E":"Estimate!!Total!!Moved within same county","B07012_010E":"Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","B07012_011E":"Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level","B07012_012E":"Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","B07012_013E":"Estimate!!Total!!Moved from different county within same state","B07012_014E":"Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                              "B07012_015E":"Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","B07012_016E":"Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","B07012_017E":"Estimate!!Total!!Moved from different state","B07012_018E":"Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level",
                                              "B07012_019E":"Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level",
                                              "B07012_020E":"Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level","B07012_021E":"Estimate!!Total!!Moved from abroad",
                                              "B07012_022E":"Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level",
                                              "B07012_023E":"Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level",
                                              "B07012_024E":"Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level",                                                               
                                              "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
poverty_level_2011= poverty_level_2011 [["Zipcode","Estimate!!Total","Estimate!!Total!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!100 to 149 percent of the poverty level","Estimate!!Total!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago","Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county","Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different county within same state","Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different state",
                                         "Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved from abroad","Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level"]]

# Visualize
print(len(poverty_level_2011))

# Save to csv
poverty_level_2011.to_csv('poverty_level_2011_EO.csv',index=False)

poverty_level_2011
# Out:
# 133
#     Zipcode  Estimate!!Total  \
# 0     77002           4109.0
# 1     77003           9517.0
# 2     77004          24467.0
# 3     77005          23477.0
# 4     77006          19862.0
# 5     77007          27216.0
# 6     77008          28867.0
# 7     77009          37690.0
# 8     77010            198.0
# 9     77011          19932.0
# 10    77012          20552.0
# 11    77013          18429.0
# 12    77014          28621.0
# 13    77015          52677.0
# 14    77016          26490.0
# 15    77017          33134.0
# 16    77018          26580.0
# 17    77019          19727.0
# 18    77020          26466.0
# 19    77021          24359.0
# 20    77022          27987.0
# 21    77023          30167.0
# 22    77024          34381.0
# 23    77025          25030.0
# 24    77026          24006.0
# 25    77027          14982.0
# 26    77028          16930.0
# 27    77029          17444.0
# 28    77030          10973.0
# 29    77031          15753.0
# ...

# %%
# Poverty level from year 2012
c_poverty_level_2012 = Census(api_key, year=2012)
poverty_level_2012 = c_poverty_level_2012.acs5.get(("NAME","B07012_001E","B07012_002E","B07012_003E","B07012_004E","B07012_005E","B07012_006E","B07012_007E","B07012_008E","B07012_009E","B07012_010E","B07012_011E","B07012_012E",
                                                   "B07012_013E","B07012_014E","B07012_015E","B07012_016E","B07012_017E","B07012_018E","B07012_019E","B07012_020E","B07012_021E","B07012_022E","B07012_023E","B07012_024E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame# Poverty level from year 2012

poverty_level_2012= pd.DataFrame(poverty_level_2012)

# Column Reordering
poverty_level_2012= poverty_level_2012.rename(columns={"B07012_001E":"Estimate!!Total","B07012_002E":"Estimate!!Total!!Below 100 percent of the poverty level","B07012_003E":"Estimate!!Total!!100 to 149 percent of the poverty level","B07012_004E":"Estimate!!Total!!At or above 150 percent of the poverty level","B07012_005E":"Estimate!!Total!!Same house 1 year ago","B07012_006E":"Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level","B07012_007E":"Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","B07012_008E":"Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                              "B07012_009E":"Estimate!!Total!!Moved within same county","B07012_010E":"Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","B07012_011E":"Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level","B07012_012E":"Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","B07012_013E":"Estimate!!Total!!Moved from different county within same state","B07012_014E":"Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                              "B07012_015E":"Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","B07012_016E":"Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","B07012_017E":"Estimate!!Total!!Moved from different state","B07012_018E":"Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level",
                                              "B07012_019E":"Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level",
                                              "B07012_020E":"Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level","B07012_021E":"Estimate!!Total!!Moved from abroad",
                                              "B07012_022E":"Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level",
                                              "B07012_023E":"Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level",
                                              "B07012_024E":"Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level",                                                               
                                              "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
poverty_level_2012= poverty_level_2012 [["Zipcode","Estimate!!Total","Estimate!!Total!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!100 to 149 percent of the poverty level","Estimate!!Total!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago","Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county","Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different county within same state","Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different state",
                                         "Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved from abroad","Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level"]]

# Visualize
print(len(poverty_level_2012))

# Save to csv
poverty_level_2012.to_csv('poverty_level_2012_EO.csv',index=False)

poverty_level_2012
# Out:
# 133
#     Zipcode  Estimate!!Total  \
# 0     77484          10692.0
# 1     77493          22141.0
# 2     77502          35276.0
# 3     77503          23423.0
# 4     77504          23744.0
# 5     77505          22923.0
# 6     77506          35862.0
# 7     77507              0.0
# 8     77520          36275.0
# 9     77521          48275.0
# 10    77530          30075.0
# 11    77532          25951.0
# 12    77536          30368.0
# 13    77547           9847.0
# 14    77562          10752.0
# 15    77571          34976.0
# 16    77586          21140.0
# 17    77587          16336.0
# 18    77598          23276.0
# 19    77002           4273.0
# 20    77003          10000.0
# 21    77004          24557.0
# 22    77005          23009.0
# 23    77006          19221.0
# 24    77007          29133.0
# 25    77008          28518.0
# 26    77009          38052.0
# 27    77010            342.0
# 28    77011          19163.0
# 29    77012          21094.0
# ...

# %%
# Poverty level from year 2013
c_poverty_level_2013 = Census(api_key, year=2013)
poverty_level_2013 = c_poverty_level_2013.acs5.get(("NAME","B07012_001E","B07012_002E","B07012_003E","B07012_004E","B07012_005E","B07012_006E","B07012_007E","B07012_008E","B07012_009E","B07012_010E","B07012_011E","B07012_012E",
                                                   "B07012_013E","B07012_014E","B07012_015E","B07012_016E","B07012_017E","B07012_018E","B07012_019E","B07012_020E","B07012_021E","B07012_022E","B07012_023E","B07012_024E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame# Poverty level from year 2013

poverty_level_2013= pd.DataFrame(poverty_level_2013)

# Column Reordering
poverty_level_2013= poverty_level_2013.rename(columns={"B07012_001E":"Estimate!!Total","B07012_002E":"Estimate!!Total!!Below 100 percent of the poverty level","B07012_003E":"Estimate!!Total!!100 to 149 percent of the poverty level","B07012_004E":"Estimate!!Total!!At or above 150 percent of the poverty level","B07012_005E":"Estimate!!Total!!Same house 1 year ago","B07012_006E":"Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level","B07012_007E":"Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","B07012_008E":"Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                              "B07012_009E":"Estimate!!Total!!Moved within same county","B07012_010E":"Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","B07012_011E":"Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level","B07012_012E":"Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","B07012_013E":"Estimate!!Total!!Moved from different county within same state","B07012_014E":"Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                              "B07012_015E":"Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","B07012_016E":"Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","B07012_017E":"Estimate!!Total!!Moved from different state","B07012_018E":"Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level",
                                              "B07012_019E":"Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level",
                                              "B07012_020E":"Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level","B07012_021E":"Estimate!!Total!!Moved from abroad",
                                              "B07012_022E":"Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level",
                                              "B07012_023E":"Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level",
                                              "B07012_024E":"Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level",                                                               
                                              "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
poverty_level_2013= poverty_level_2013 [["Zipcode","Estimate!!Total","Estimate!!Total!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!100 to 149 percent of the poverty level","Estimate!!Total!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago","Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county","Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different county within same state","Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different state",
                                         "Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved from abroad","Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level"]]

# Visualize
print(len(poverty_level_2013))

# Save to csv
poverty_level_2013.to_csv('poverty_level_2013_EO.csv',index=False)

poverty_level_2013
# Out:
# 133
#     Zipcode  Estimate!!Total  \
# 0     77562          10674.0
# 1     77571          35284.0
# 2     77586          21540.0
# 3     77587          16379.0
# 4     77598          22945.0
# 5     77002           4511.0
# 6     77003          10447.0
# 7     77004          25535.0
# 8     77005          22893.0
# 9     77006          19936.0
# 10    77007          30465.0
# 11    77008          29844.0
# 12    77009          38733.0
# 13    77010            564.0
# 14    77011          19164.0
# 15    77012          21415.0
# 16    77013          18017.0
# 17    77014          29904.0
# 18    77015          55781.0
# 19    77016          26441.0
# 20    77017          32602.0
# 21    77018          26069.0
# 22    77019          19656.0
# 23    77020          26168.0
# 24    77021          24729.0
# 25    77022          28153.0
# 26    77023          29400.0
# 27    77024          34891.0
# 28    77025          25923.0
# 29    77026          22448.0
# ...

# %%
# Poverty level from year 2014
c_poverty_level_2014 = Census(api_key, year=2014)
poverty_level_2014 = c_poverty_level_2014.acs5.get(("NAME","B07012_001E","B07012_002E","B07012_003E","B07012_004E","B07012_005E","B07012_006E","B07012_007E","B07012_008E","B07012_009E","B07012_010E","B07012_011E","B07012_012E",
                                                   "B07012_013E","B07012_014E","B07012_015E","B07012_016E","B07012_017E","B07012_018E","B07012_019E","B07012_020E","B07012_021E","B07012_022E","B07012_023E","B07012_024E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame# Poverty level from year 2014

poverty_level_2014= pd.DataFrame(poverty_level_2014)

# Column Reordering
poverty_level_2014= poverty_level_2014.rename(columns={"B07012_001E":"Estimate!!Total","B07012_002E":"Estimate!!Total!!Below 100 percent of the poverty level","B07012_003E":"Estimate!!Total!!100 to 149 percent of the poverty level","B07012_004E":"Estimate!!Total!!At or above 150 percent of the poverty level","B07012_005E":"Estimate!!Total!!Same house 1 year ago","B07012_006E":"Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level","B07012_007E":"Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","B07012_008E":"Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                              "B07012_009E":"Estimate!!Total!!Moved within same county","B07012_010E":"Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","B07012_011E":"Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level","B07012_012E":"Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","B07012_013E":"Estimate!!Total!!Moved from different county within same state","B07012_014E":"Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                              "B07012_015E":"Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","B07012_016E":"Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","B07012_017E":"Estimate!!Total!!Moved from different state","B07012_018E":"Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level",
                                              "B07012_019E":"Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level",
                                              "B07012_020E":"Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level","B07012_021E":"Estimate!!Total!!Moved from abroad",
                                              "B07012_022E":"Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level",
                                              "B07012_023E":"Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level",
                                              "B07012_024E":"Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level",                                                               
                                              "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
poverty_level_2014= poverty_level_2014 [["Zipcode","Estimate!!Total","Estimate!!Total!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!100 to 149 percent of the poverty level","Estimate!!Total!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago","Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county","Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different county within same state","Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different state",
                                         "Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved from abroad","Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level"]]

# Visualize
print(len(poverty_level_2014))

# Save to csv
poverty_level_2014.to_csv('poverty_level_2014_EO.csv',index=False)

poverty_level_2014
# Out:
# 133
#     Zipcode  Estimate!!Total  \
# 0     77520          37111.0
# 1     77521          52154.0
# 2     77530          29725.0
# 3     77532          27900.0
# 4     77536          31292.0
# 5     77547           9789.0
# 6     77562          10686.0
# 7     77571          35729.0
# 8     77586          21555.0
# 9     77587          16759.0
# 10    77598          23772.0
# 11    77002           4454.0
# 12    77003          10608.0
# 13    77004          26461.0
# 14    77005          23221.0
# 15    77006          20538.0
# 16    77007          31574.0
# 17    77008          30503.0
# 18    77009          38451.0
# 19    77010            724.0
# 20    77011          18872.0
# 21    77012          20601.0
# 22    77013          19688.0
# 23    77014          31269.0
# 24    77015          54124.0
# 25    77016          26031.0
# 26    77017          33470.0
# 27    77018          26368.0
# 28    77019          20013.0
# 29    77020          25991.0
# ...

# %%
# Poverty level from year 2015
c_poverty_level_2015 = Census(api_key, year=2015)
poverty_level_2015 = c_poverty_level_2015.acs5.get(("NAME","B07012_001E","B07012_002E","B07012_003E","B07012_004E","B07012_005E","B07012_006E","B07012_007E","B07012_008E","B07012_009E","B07012_010E","B07012_011E","B07012_012E",
                                                   "B07012_013E","B07012_014E","B07012_015E","B07012_016E","B07012_017E","B07012_018E","B07012_019E","B07012_020E","B07012_021E","B07012_022E","B07012_023E","B07012_024E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame# Poverty level from year 2015

poverty_level_2015= pd.DataFrame(poverty_level_2015)

# Column Reordering
poverty_level_2015= poverty_level_2015.rename(columns={"B07012_001E":"Estimate!!Total","B07012_002E":"Estimate!!Total!!Below 100 percent of the poverty level","B07012_003E":"Estimate!!Total!!100 to 149 percent of the poverty level","B07012_004E":"Estimate!!Total!!At or above 150 percent of the poverty level","B07012_005E":"Estimate!!Total!!Same house 1 year ago","B07012_006E":"Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level","B07012_007E":"Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","B07012_008E":"Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                              "B07012_009E":"Estimate!!Total!!Moved within same county","B07012_010E":"Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","B07012_011E":"Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level","B07012_012E":"Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","B07012_013E":"Estimate!!Total!!Moved from different county within same state","B07012_014E":"Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                              "B07012_015E":"Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","B07012_016E":"Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","B07012_017E":"Estimate!!Total!!Moved from different state","B07012_018E":"Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level",
                                              "B07012_019E":"Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level",
                                              "B07012_020E":"Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level","B07012_021E":"Estimate!!Total!!Moved from abroad",
                                              "B07012_022E":"Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level",
                                              "B07012_023E":"Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level",
                                              "B07012_024E":"Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level",                                                               
                                              "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
poverty_level_2015= poverty_level_2015 [["Zipcode","Estimate!!Total","Estimate!!Total!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!100 to 149 percent of the poverty level","Estimate!!Total!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago","Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county","Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different county within same state","Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different state",
                                         "Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved from abroad","Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level"]]

# Visualize
print(len(poverty_level_2015))

# Save to csv
poverty_level_2015.to_csv('poverty_level_2015_EO.csv',index=False)

poverty_level_2015
# Out:
# 133
#     Zipcode  Estimate!!Total  \
# 0     77002           4778.0
# 1     77003          10316.0
# 2     77004          26827.0
# 3     77005          24058.0
# 4     77006          21053.0
# 5     77007          32684.0
# 6     77008          30933.0
# 7     77009          38595.0
# 8     77010            809.0
# 9     77011          19044.0
# 10    77012          20103.0
# 11    77013          19614.0
# 12    77014          33230.0
# 13    77015          55756.0
# 14    77016          26012.0
# 15    77017          33062.0
# 16    77018          26857.0
# 17    77019          20373.0
# 18    77020          25475.0
# 19    77021          25573.0
# 20    77022          27850.0
# 21    77023          27906.0
# 22    77024          36507.0
# 23    77025          27838.0
# 24    77026          22122.0
# 25    77027          15502.0
# 26    77028          14389.0
# 27    77029          17527.0
# 28    77030           9870.0
# 29    77031          18009.0
# ...

# %%
# Poverty level from year 2016
c_poverty_level_2016 = Census(api_key, year=2016)
poverty_level_2016 = c_poverty_level_2016.acs5.get(("NAME","B07012_001E","B07012_002E","B07012_003E","B07012_004E","B07012_005E","B07012_006E","B07012_007E","B07012_008E","B07012_009E","B07012_010E","B07012_011E","B07012_012E",
                                                   "B07012_013E","B07012_014E","B07012_015E","B07012_016E","B07012_017E","B07012_018E","B07012_019E","B07012_020E","B07012_021E","B07012_022E","B07012_023E","B07012_024E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame# Poverty level from year 2016

poverty_level_2016= pd.DataFrame(poverty_level_2016)

# Column Reordering
poverty_level_2016= poverty_level_2016.rename(columns={"B07012_001E":"Estimate!!Total","B07012_002E":"Estimate!!Total!!Below 100 percent of the poverty level","B07012_003E":"Estimate!!Total!!100 to 149 percent of the poverty level","B07012_004E":"Estimate!!Total!!At or above 150 percent of the poverty level","B07012_005E":"Estimate!!Total!!Same house 1 year ago","B07012_006E":"Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level","B07012_007E":"Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","B07012_008E":"Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                              "B07012_009E":"Estimate!!Total!!Moved within same county","B07012_010E":"Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","B07012_011E":"Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level","B07012_012E":"Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","B07012_013E":"Estimate!!Total!!Moved from different county within same state","B07012_014E":"Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                              "B07012_015E":"Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","B07012_016E":"Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","B07012_017E":"Estimate!!Total!!Moved from different state","B07012_018E":"Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level",
                                              "B07012_019E":"Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level",
                                              "B07012_020E":"Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level","B07012_021E":"Estimate!!Total!!Moved from abroad",
                                              "B07012_022E":"Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level",
                                              "B07012_023E":"Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level",
                                              "B07012_024E":"Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level",                                                               
                                              "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
poverty_level_2016= poverty_level_2016 [["Zipcode","Estimate!!Total","Estimate!!Total!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!100 to 149 percent of the poverty level","Estimate!!Total!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago","Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county","Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different county within same state","Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different state",
                                         "Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved from abroad","Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level"]]

# Visualize
print(len(poverty_level_2016))

# Save to csv
poverty_level_2016.to_csv('poverty_level_2016_EO.csv',index=False)

poverty_level_2016
# Out:
# 133
#     Zipcode  Estimate!!Total  \
# 0     77586          21697.0
# 1     77587          16501.0
# 2     77598          23505.0
# 3     77002           4911.0
# 4     77003          10009.0
# 5     77004          27456.0
# 6     77005          24477.0
# 7     77006          21131.0
# 8     77007          34780.0
# 9     77008          31645.0
# 10    77009          37389.0
# 11    77010            831.0
# 12    77011          18286.0
# 13    77012          20115.0
# 14    77013          19231.0
# 15    77014          33327.0
# 16    77015          56183.0
# 17    77016          26972.0
# 18    77017          32038.0
# 19    77018          27503.0
# 20    77019          20765.0
# 21    77020          25439.0
# 22    77021          25762.0
# 23    77022          27342.0
# 24    77023          27585.0
# 25    77024          37275.0
# 26    77025          27669.0
# 27    77026          22650.0
# 28    77027          15277.0
# 29    77028          14254.0
# ...

# %%
# Poverty level from year 2017
c_poverty_level_2017 = Census(api_key, year=2017)
poverty_level_2017 = c_poverty_level_2017.acs5.get(("NAME","B07012_001E","B07012_002E","B07012_003E","B07012_004E","B07012_005E","B07012_006E","B07012_007E","B07012_008E","B07012_009E","B07012_010E","B07012_011E","B07012_012E",
                                                   "B07012_013E","B07012_014E","B07012_015E","B07012_016E","B07012_017E","B07012_018E","B07012_019E","B07012_020E","B07012_021E","B07012_022E","B07012_023E","B07012_024E"), 
                                                               {'for': 'zip code tabulation area:77484,77001,    77002,    77003,    77004,    77005,    77005,    77006,    77007,    77008,    77009,    77010,    77011,    77012,    77013,    77014,    77015,    77016,    77017,    77018,    77019,    77020,    77021,    77022,    77023,    77024,    77025,    77026,    77027,    77028,    77029,    77029,    77030,    77030,    77031,    77032,    77033,    77034,    77035,    77036,    77037,    77038,    77039,    77040,    77040,    77041,    77041,    77042,    77043,    77044,    77045,    77046,    77046,    77047,    77048,    77049,    77050,    77051,    77052,    77054,    77055,    77056,    77057,    77058,    77059,    77060,    77061,    77062,    77063,    77064,    77065,    77065,    77066,    77067,    77068,    77069,    77070,    77071,    77072,    77073,    77074,    77075,    77076,    77077,    77078,    77079,    77080,    77081,    77082,    77083,    77084,    77085,    77086,    77087,    77088,    77089,    77090,    77091,    77092,    77093,    77094,    77095,    77096,    77097,    77098,    77099,    77201,    77202,    77203,    77205,    77206,    77207,    77208,    77210,    77213,    77215,    77217,    77218,    77219,    77220,    77221,    77222,    77223,    77224,    77225,    77226,    77227,    77228,    77229,    77230,    77231,    77233,    77234,    77235,    77236,    77237,    77238,    77240,    77241,    77242,    77243,    77244,    77245,    77248,    77249,    77251,    77252,    77253,    77254,    77255,    77256,    77257,    77258,    77259,    77261,    77262,    77263,    77265,    77266,    77267,    77268,    77269,    77270,    77271,    77272,    77273,    77274,    77275,    77277,    77279,    77280,    77281,    77282,    77284,    77287,    77288,    77289,    77290,    77291,    77292,    77293,    77315,    77325,    77325,    77336,    77337,    77337,    77338,    77339,    77339,    77345,    77345,    77346,    77346,    77346,    77347,    77373,    77375,    77377,    77379,    77379,    77383,    77388,    77389,    77389,    77391,    77396,    77401,    77402,    77410,    77411,    77413,    77429,    77433,    77447,    77449,    77449,    77450,    77450,    77491,    77492,    77493,    77493,    77501,    77502,    77503,    77504,    77505,    77506,    77507,    77508,    77520,    77521,    77522,    77530,    77532,    77532,    77536,    77547,    77562,    77571,    77571,    77572,    77586,    77586,    77586,    77587, 77598'})

# %%
# Convert to DataFrame# Poverty level from year 2017

poverty_level_2017= pd.DataFrame(poverty_level_2017)

# Column Reordering
poverty_level_2017= poverty_level_2017.rename(columns={"B07012_001E":"Estimate!!Total","B07012_002E":"Estimate!!Total!!Below 100 percent of the poverty level","B07012_003E":"Estimate!!Total!!100 to 149 percent of the poverty level","B07012_004E":"Estimate!!Total!!At or above 150 percent of the poverty level","B07012_005E":"Estimate!!Total!!Same house 1 year ago","B07012_006E":"Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level","B07012_007E":"Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","B07012_008E":"Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                              "B07012_009E":"Estimate!!Total!!Moved within same county","B07012_010E":"Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","B07012_011E":"Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level","B07012_012E":"Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","B07012_013E":"Estimate!!Total!!Moved from different county within same state","B07012_014E":"Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                              "B07012_015E":"Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","B07012_016E":"Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","B07012_017E":"Estimate!!Total!!Moved from different state","B07012_018E":"Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level",
                                              "B07012_019E":"Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level",
                                              "B07012_020E":"Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level","B07012_021E":"Estimate!!Total!!Moved from abroad",
                                              "B07012_022E":"Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level",
                                              "B07012_023E":"Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level",
                                              "B07012_024E":"Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level",                                                               
                                              "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Final DataFrame
poverty_level_2017= poverty_level_2017 [["Zipcode","Estimate!!Total","Estimate!!Total!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!100 to 149 percent of the poverty level","Estimate!!Total!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago","Estimate!!Total!!Same house 1 year ago!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Same house 1 year ago!!100 to 149 percent of the poverty level","Estimate!!Total!!Same house 1 year ago!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county","Estimate!!Total!!Moved within same county!!Below 100 percent of the poverty level","Estimate!!Total!!Moved within same county!!100 to 149 percent of the poverty level",
                                         "Estimate!!Total!!Moved within same county!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different county within same state","Estimate!!Total!!Moved from different county within same state!!Below 100 percent of the poverty level",
                                         "Estimate!!Total!!Moved from different county within same state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different county within same state!!At or above 150 percent of the poverty level","Estimate!!Total!!Moved from different state",
                                         "Estimate!!Total!!Moved from different state!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from different state!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from different state!!At or above 150 percent of the poverty level",
                                         "Estimate!!Total!!Moved from abroad","Estimate!!Total!!Moved from abroad!!Below 100 percent of the poverty level","Estimate!!Total!!Moved from abroad!!100 to 149 percent of the poverty level","Estimate!!Total!!Moved from abroad!!At or above 150 percent of the poverty level"]]

# Visualize
print(len(poverty_level_2017))

# Save to csv
poverty_level_2017.to_csv('poverty_level_2017_EO.csv',index=False)

poverty_level_2017
# Out:
# 133
#     Zipcode  Estimate!!Total  \
# 0     77003           9513.0
# 1     77375          49095.0
# 2     77002           4916.0
# 3     77091          24828.0
# 4     77024          37508.0
# 5     77036          74800.0
# 6     77046           1003.0
# 7     77049          33245.0
# 8     77061          25831.0
# 9     77073          41763.0
# 10    77076          34086.0
# 11    77079          33187.0
# 12    77080          44848.0
# 13    77087          36076.0
# 14    77092          37687.0
# 15    77095          70891.0
# 16    77016          28890.0
# 17    77018          27501.0
# 18    77029          17383.0
# 19    77044          41859.0
# 20    77048          17002.0
# 21    77051          16142.0
# 22    77066          33405.0
# 23    77054          22122.0
# 24    77059          17214.0
# 25    77062          25909.0
# 26    77075          42995.0
# 27    77078          15590.0
# 28    77085          17705.0
# 29    77484          10521.0
# ...
