# %%
# Dependencies
import requests
import json
from config import api_key
from config import gkey
import census
from census import Census
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import csv
import us
from us import states

# %%
# Load Files
HH_ave_Workforce2011_Clean_data = "HH_ave_Workforce2011_Clean_NN-EO.csv"
HH_ave_Workforce2012_Clean_data = "HH_ave_Workforce2012_Clean_NN-EO.csv"
HH_ave_Workforce2013_Clean_data = "HH_ave_Workforce2013_Clean_NN-EO.csv"
HH_ave_Workforce2014_Clean_data = "HH_ave_Workforce2014_Clean_NN-EO.csv"
HH_ave_Workforce2015_Clean_data = "HH_ave_Workforce2015_Clean_NN-EO.csv"
HH_ave_Workforce2016_Clean_data = "HH_ave_Workforce2016_Clean_NN-EO.csv"
HH_ave_Workforce2017_Clean_data = "HH_ave_Workforce2017_Clean_NN-EO.csv"


HH_Value_And_Cost2011_Clean_NN_data = "HH_Value_And_Cost2011_Clean_NN.csv"
HH_Value_And_Cost2012_Clean_NN_data = "HH_Value_And_Cost2012_Clean_NN.csv"
HH_Value_And_Cost2013_Clean_NN_data = "HH_Value_And_Cost2013_Clean_NN.csv"
HH_Value_And_Cost2014_Clean_NN_data = "HH_Value_And_Cost2014_Clean_NN.csv"
HH_Value_And_Cost2015_Clean_NN_data = "HH_Value_And_Cost2015_Clean_NN.csv"
HH_Value_And_Cost2016_Clean_NN_data = "HH_Value_And_Cost2016_Clean_NN.csv"
HH_Value_And_Cost2017_Clean_NN_data = "HH_Value_And_Cost2017_Clean_NN.csv"


HH_ave_Workforce2011_Clean_data = pd.read_csv(HH_ave_Workforce2011_Clean_data,encoding="UTF-8")
HH_ave_Workforce2012_Clean_data = pd.read_csv(HH_ave_Workforce2012_Clean_data,encoding="UTF-8")
HH_ave_Workforce2013_Clean_data = pd.read_csv(HH_ave_Workforce2013_Clean_data,encoding="UTF-8")
HH_ave_Workforce2014_Clean_data = pd.read_csv(HH_ave_Workforce2014_Clean_data,encoding="UTF-8")
HH_ave_Workforce2015_Clean_data = pd.read_csv(HH_ave_Workforce2015_Clean_data,encoding="UTF-8")
HH_ave_Workforce2016_Clean_data = pd.read_csv(HH_ave_Workforce2016_Clean_data,encoding="UTF-8")
HH_ave_Workforce2017_Clean_data = pd.read_csv(HH_ave_Workforce2017_Clean_data,encoding="UTF-8")

HH_Value_And_Cost2011_Clean_NN_data = pd.read_csv(HH_Value_And_Cost2011_Clean_NN_data,encoding="UTF-8")
HH_Value_And_Cost2012_Clean_NN_data = pd.read_csv(HH_Value_And_Cost2012_Clean_NN_data,encoding="UTF-8")
HH_Value_And_Cost2013_Clean_NN_data = pd.read_csv(HH_Value_And_Cost2013_Clean_NN_data,encoding="UTF-8")
HH_Value_And_Cost2014_Clean_NN_data = pd.read_csv(HH_Value_And_Cost2014_Clean_NN_data,encoding="UTF-8")
HH_Value_And_Cost2015_Clean_NN_data = pd.read_csv(HH_Value_And_Cost2015_Clean_NN_data,encoding="UTF-8")
HH_Value_And_Cost2016_Clean_NN_data = pd.read_csv(HH_Value_And_Cost2016_Clean_NN_data,encoding="UTF-8")
HH_Value_And_Cost2017_Clean_NN_data = pd.read_csv(HH_Value_And_Cost2017_Clean_NN_data,encoding="UTF-8")


HH_Value_And_Cost2017_Clean_NN_data=HH_Value_And_Cost2017_Clean_NN_data.drop([127,112,16,93,36,30])

# %%
#HH_Value_And_Cost2012_Clean_NN_data=HH_Value_And_Cost2017_Clean_NN_data.drop([])

HH_Value_And_Cost2012_Clean_NN_data.sort_values(by="Upper value quartile (dollars)")
# Out:
#      Zipcode  Total Housing Unit  Median Value  \
# 66   77051.0              6721.0       54400.0
# 48   77033.0             10186.0       65000.0
# 31   77016.0             10820.0       65200.0
# 43   77028.0              6682.0       61000.0
# 41   77026.0             10498.0       59900.0
# 91   77078.0              5244.0       67700.0
# 6    77506.0             12210.0       75600.0
# 12   77547.0              2812.0       70600.0
# 44   77029.0              6315.0       73600.0
# 65   77050.0              1416.0       76400.0
# 26   77011.0              6957.0       78300.0
# 35   77020.0              9688.0       71900.0
# 47   77032.0              4607.0       73100.0
# 106  77093.0             13660.0       76700.0
# 27   77012.0              7346.0       80600.0
# 100  77087.0             11982.0       85700.0
# 63   77048.0              6562.0       83300.0
# 89   77076.0             10001.0       85800.0
# 60   77045.0             10110.0       87900.0
# ...

# %%
HH_ave_Workforce2012_Clean_data.sort_values(by)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-3ec9f258fbcc> in <module>
# ----> 1 HH_ave_Workforce2012_Clean_data.sort_values(by)
#
# NameError: name 'by' is not defined

# %%
plt.figure(figsize=(20,10))
plt.scatter(HH_ave_Workforce2011_Clean_data['Average_Travel_Time'],HH_Value_And_Cost2011_Clean_NN_data['Upper value quartile (dollars)'], marker='o', facecolor='green', 
         s=12, color='skyblue', linewidth=4)

# %%
HH_ave_Workforce2012_Clean_data

# %%
HH_Value_And_Cost2012_Clean_NN_data.sort_values(by='Upper value quartile (dollars)')
